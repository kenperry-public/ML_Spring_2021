# %%
# My standard magic !  You will see this in almost all my notebooks.

from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# Reload all modules imported with %aimport
# %load_ext autoreload
# %autoreload 1

# %matplotlib inline

# %%
import publish_helper
# %aimport publish_helper

# %%
REPO="Spring_2021"

root_nb="Index.ipynb"
# %cd ~/Notebooks/release/NYU/$REPO
# Out:
# /home/kjp/Notebooks/release/NYU/Spring_2021

# %%
ph = publish_helper.Publish()
ph.preview(root_nb=root_nb)
# Out:
# http://localhost:8888/notebooks/NYU/Transformations.ipynb  is NOT local
# Notebooks:
# 	Bias_and_Variance.ipynb
# 	Categorical_Variables.ipynb
# 	Choosing_an_ML_Environment_NYU.ipynb
# 	Classification_Baseline_Model.ipynb
# 	Classification_Log_Odds.ipynb
# 	Classification_Loss_Function.ipynb
# 	Classification_Notebook_Overview.ipynb
# 	Classification_Overview.ipynb
# 	Classification_and_Non_Numerical_Data.ipynb
# 	Course_overview_NYU.ipynb
# 	Dummy_Variable_Trap.ipynb
# 	Error_Analysis.ipynb
# 	Error_Analysis_MNIST.ipynb
# 	Error_Analysis_Overview.ipynb
# 	Fine_tuning.ipynb
# 	Getting_Started.ipynb
# 	Index.ipynb
# 	Intro_Classical_ML.ipynb
# 	Jupyter_quick_tour.ipynb
# 	Latex_macros.ipynb
# 	Linear_Regression_HigherOrderFeatures.ipynb
# 	Linear_Regression_Loss_Function.ipynb
# 	Linear_Regression_Overview.ipynb
# 	Loss_functions.ipynb
# 	ML_Notation.ipynb
# 	ML_Overview.ipynb
# 	Multinomial_Classification.ipynb
# 	NumPy_quick_tour.ipynb
# 	Pandas_quick_tour.ipynb
# 	Prepare_data_Overview.ipynb
# 	Recipe_Overview.ipynb
# 	Recipe_for_ML.ipynb
# 	Sample.ipynb
# 	Setup_ML_Environment_NYU.ipynb
# 	Setup_NYU.ipynb
# 	Training_Loss.ipynb
# 	Transformations.ipynb
# 	Transformations_Mechanics.ipynb
# 	Transformations_Overview.ipynb
# 	Transformations_Pipelines.ipynb
# 	assignments/Assignment_Guidelines.ipynb
# 	assignments/Regression task/Using_Machine_Learning_for_Hedging.ipynb
# 	beautify_plots.py
#
# Images:
#
# 	./images/data.png
# 	./images/test_data.png
# 	./images/train_data.png
# 	external/PythonDataScienceHandbook/notebooks/figures/02.05-broadcasting.png
# 	external/PythonDataScienceHandbook/notebooks/figures/03.08-split-apply-combine.png
# 	images/AnacondaNavigator.png
# 	images/Back_to_parent.jpg
# 	images/Cross_validation.png
# 	images/Feature_engineering.png
# 	images/Feature_engineering_fit.png
# 	images/Install_TensorFlow.png
# 	images/Install_git_and_get_repo.png
# 	images/Intro_error_analysis_1.png
# 	images/Jupyter_create_notebook_dir.png
# 	images/Jupyter_install_extensions.png
# 	images/Start_navigator.png
# 	images/Titanic_cabin_layout.jpg
# 	images/W1_L1_Anomaly-detection_AdobeStock_311611620.png
# 	images/W1_L1_Bottom_up.png
# 	images/W1_L1_Cartoon_ML.png
# 	images/W1_L1_Challenge.png
# 	images/W1_L1_Engineer.png
# 	images/W1_L1_Forecasting_sales_AdobeStock_307330168-[Converted].png
# 	images/W1_L1_Informed-Prediction_AdobeStock_339315304.png
# 	images/W1_L1_Medium_level_view_AdobeStock_316627761.png
# 	images/W1_L1_Predicting_on_Unseen-data_AdobeStock_321987501.png
# 	images/W1_L1_Programming.png
# 	images/W1_L1_Satellite_image_cars_AdobeStock_130994721.png
# 	images/W1_L1_Scientist.png
# 	images/W1_L1_Self-motivation.png
# 	images/W1_L1_Spam_detection_AdobeStock_354630313.png
# 	images/W1_L1_Stats.png
# 	images/W1_L1_Targeted_advertising_AdobeStock_320775942.png
# 	images/W1_L1_Textbook_Geron.jpeg
# 	images/W1_L1_Textbook_VanderPlas.png
# 	images/W1_L1_Top_down.png
# 	images/W1_L1_Trading_signals_AdobeStock_188236125.png
# 	images/W1_L1_iterative.png
# 	images/W1_L3_S34_KNN_algo.png
# 	images/W1_L3_S4_ML_Process.png
# 	images/W1_L3_S9_Big_picture_ML_taxonomy.png
# 	images/W1_L4_S11_Terminology_training_linear_regr.png
# 	images/W1_L4_S9_Intro_training_2.png
# 	images/W1_L4_s15_Intro_training.jpg
# 	images/W1_L4_s55_Intro_training.png
# 	images/W2_L0_S4_Terminology_training.png
# 	images/W2_L2_S15_Performance_measure.png
# 	images/W2_L2_S27_ML_process_iterate.png
# 	images/W2_L3_S83_Train_Test_Validation.png
# 	images/W2_L3_S88_Train_Test_Validation_Fold.png
# 	images/W3_L1_S3_Feature_engineering.png
# 	images/W4_L4_Intro_error_analysis.png
# 	images/chicago.jpg
# 	images/chicago_starry_night.jpg
# 	images/class_overview_prob_lines.jpg
# 	images/mnist_small_test.png
# 	images/mnist_small_train.png
# 	images/starry_night_crop.jpg
#
# Imports:
#
# 	assignments/Regression task/helper.py
# 	class_helper.py
# 	mnist_helper.py
# 	recipe_helper.py
# 	svm_helper.py
# 	training_models_helper.py
# 	transform_helper.py
#
# Remote links:
#
# 	Transformations.ipynb
#
# CSV files:

# %%
# %cd ~/Notebooks/release/NYU/$REPO
# %pwd
# Out:
# /home/kjp/Notebooks/release/NYU/Spring_2021
# '/home/kjp/Notebooks/release/NYU/Spring_2021'

# %%
ph.publish(git=True, root_nb=root_nb, Debug=True)
# Out:
# http://localhost:8888/notebooks/NYU/Transformations.ipynb  is NOT local
# Run:  git add 'Bias_and_Variance.ipynb'
# Run:  git add 'Categorical_Variables.ipynb'
# Run:  git add 'Choosing_an_ML_Environment_NYU.ipynb'
# Run:  git add 'Classification_Baseline_Model.ipynb'
# Run:  git add 'Classification_Log_Odds.ipynb'
# Run:  git add 'Classification_Loss_Function.ipynb'
# Run:  git add 'Classification_Notebook_Overview.ipynb'
# Run:  git add 'Classification_Overview.ipynb'
# Run:  git add 'Classification_and_Non_Numerical_Data.ipynb'
# Run:  git add 'Course_overview_NYU.ipynb'
# Run:  git add 'Dummy_Variable_Trap.ipynb'
# Run:  git add 'Error_Analysis.ipynb'
# Run:  git add 'Error_Analysis_MNIST.ipynb'
# Run:  git add 'Error_Analysis_Overview.ipynb'
# Run:  git add 'Fine_tuning.ipynb'
# Run:  git add 'Getting_Started.ipynb'
# Run:  git add 'Index.ipynb'
# Run:  git add 'Intro_Classical_ML.ipynb'
# Run:  git add 'Jupyter_quick_tour.ipynb'
# Run:  git add 'Latex_macros.ipynb'
# Run:  git add 'Linear_Regression_HigherOrderFeatures.ipynb'
# Run:  git add 'Linear_Regression_Loss_Function.ipynb'
# Run:  git add 'Linear_Regression_Overview.ipynb'
# Run:  git add 'Loss_functions.ipynb'
# Run:  git add 'ML_Notation.ipynb'
# Run:  git add 'ML_Overview.ipynb'
# Run:  git add 'Multinomial_Classification.ipynb'
# Run:  git add 'NumPy_quick_tour.ipynb'
# Run:  git add 'Pandas_quick_tour.ipynb'
# Run:  git add 'Prepare_data_Overview.ipynb'
# Run:  git add 'Recipe_Overview.ipynb'
# Run:  git add 'Recipe_for_ML.ipynb'
# Run:  git add 'Sample.ipynb'
# Run:  git add 'Setup_ML_Environment_NYU.ipynb'
# Run:  git add 'Setup_NYU.ipynb'
# Run:  git add 'Training_Loss.ipynb'
# Run:  git add 'Transformations.ipynb'
# Run:  git add 'Transformations_Mechanics.ipynb'
# Run:  git add 'Transformations_Overview.ipynb'
# Run:  git add 'Transformations_Pipelines.ipynb'
# Run:  git add 'assignments/Assignment_Guidelines.ipynb'
# Run:  git add 'assignments/Regression task/Using_Machine_Learning_for_Hedging.ipynb'
# Run:  git add 'beautify_plots.py'
# Run:  git add './images/data.png'
# git add './images/data.png' (rc=128):
# git add './images/data.png' (rc=128)
# Run:  git add './images/test_data.png'
# git add './images/test_data.png' (rc=128):
# git add './images/test_data.png' (rc=128)
# Run:  git add './images/train_data.png'
# git add './images/train_data.png' (rc=128):
# git add './images/train_data.png' (rc=128)
# Not commiting external:  external/PythonDataScienceHandbook/notebooks/figures/02.05-broadcasting.png
# Not commiting external:  external/PythonDataScienceHandbook/notebooks/figures/03.08-split-apply-combine.png
# Run:  git add 'images/AnacondaNavigator.png'
# Run:  git add 'images/Back_to_parent.jpg'
# Run:  git add 'images/Cross_validation.png'
# Run:  git add 'images/Feature_engineering.png'
# Run:  git add 'images/Feature_engineering_fit.png'
# Run:  git add 'images/Install_TensorFlow.png'
# Run:  git add 'images/Install_git_and_get_repo.png'
# Run:  git add 'images/Intro_error_analysis_1.png'
# Run:  git add 'images/Jupyter_create_notebook_dir.png'
# Run:  git add 'images/Jupyter_install_extensions.png'
# Run:  git add 'images/Start_navigator.png'
# Run:  git add 'images/Titanic_cabin_layout.jpg'
# Run:  git add 'images/W1_L1_Anomaly-detection_AdobeStock_311611620.png'
# Run:  git add 'images/W1_L1_Bottom_up.png'
# Run:  git add 'images/W1_L1_Cartoon_ML.png'
# Run:  git add 'images/W1_L1_Challenge.png'
# Run:  git add 'images/W1_L1_Engineer.png'
# Run:  git add 'images/W1_L1_Forecasting_sales_AdobeStock_307330168-[Converted].png'
# Run:  git add 'images/W1_L1_Informed-Prediction_AdobeStock_339315304.png'
# Run:  git add 'images/W1_L1_Medium_level_view_AdobeStock_316627761.png'
# Run:  git add 'images/W1_L1_Predicting_on_Unseen-data_AdobeStock_321987501.png'
# Run:  git add 'images/W1_L1_Programming.png'
# Run:  git add 'images/W1_L1_Satellite_image_cars_AdobeStock_130994721.png'
# Run:  git add 'images/W1_L1_Scientist.png'
# Run:  git add 'images/W1_L1_Self-motivation.png'
# Run:  git add 'images/W1_L1_Spam_detection_AdobeStock_354630313.png'
# Run:  git add 'images/W1_L1_Stats.png'
# Run:  git add 'images/W1_L1_Targeted_advertising_AdobeStock_320775942.png'
# Run:  git add 'images/W1_L1_Textbook_Geron.jpeg'
# Run:  git add 'images/W1_L1_Textbook_VanderPlas.png'
# Run:  git add 'images/W1_L1_Top_down.png'
# Run:  git add 'images/W1_L1_Trading_signals_AdobeStock_188236125.png'
# Run:  git add 'images/W1_L1_iterative.png'
# Run:  git add 'images/W1_L3_S34_KNN_algo.png'
# Run:  git add 'images/W1_L3_S4_ML_Process.png'
# Run:  git add 'images/W1_L3_S9_Big_picture_ML_taxonomy.png'
# Run:  git add 'images/W1_L4_S11_Terminology_training_linear_regr.png'
# Run:  git add 'images/W1_L4_S9_Intro_training_2.png'
# Run:  git add 'images/W1_L4_s15_Intro_training.jpg'
# Run:  git add 'images/W1_L4_s55_Intro_training.png'
# Run:  git add 'images/W2_L0_S4_Terminology_training.png'
# Run:  git add 'images/W2_L2_S15_Performance_measure.png'
# Run:  git add 'images/W2_L2_S27_ML_process_iterate.png'
# Run:  git add 'images/W2_L3_S83_Train_Test_Validation.png'
# Run:  git add 'images/W2_L3_S88_Train_Test_Validation_Fold.png'
# Run:  git add 'images/W3_L1_S3_Feature_engineering.png'
# Run:  git add 'images/W4_L4_Intro_error_analysis.png'
# Run:  git add 'images/chicago.jpg'
# Run:  git add 'images/chicago_starry_night.jpg'
# Run:  git add 'images/class_overview_prob_lines.jpg'
# Run:  git add 'images/mnist_small_test.png'
# Run:  git add 'images/mnist_small_train.png'
# Run:  git add 'images/starry_night_crop.jpg'
# Run:  git add 'assignments/Regression task/helper.py'
# Run:  git add 'class_helper.py'
# Run:  git add 'mnist_helper.py'
# Run:  git add 'recipe_helper.py'
# Run:  git add 'svm_helper.py'
# Run:  git add 'training_models_helper.py'
# Run:  git add 'transform_helper.py'
# Run:  git add 'Transformations.ipynb'

# %% [markdown]
# # Need to have the post-processor running on port :8000
# - allows printing to work
# - need to interrupt it after it starts in order to be able to run following cell

# %%
! jupyter nbconvert --to slides $root_nb  `ii--post serve
# Out:
# [NbConvertApp] Converting notebook Index.ipynb to slides
# [NbConvertApp] Writing 285907 bytes to Index.slides.html
# [NbConvertApp] Redirecting reveal.js requests to https://cdnjs.cloudflare.com/ajax/libs/reveal.js/3.5.0
# Serving your slides at http://127.0.0.1:8000/Index.slides.html
# Use Control-C to stop this server
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.39ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.35ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.42ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.49ms
# WARNING:tornado.access:404 GET /favicon.ico (127.0.0.1) 0.41ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.37ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.35ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.40ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.37ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.40ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.35ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.43ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.35ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.41ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 40.01ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.36ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.34ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.43ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.33ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.36ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.35ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.38ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.42ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.43ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.35ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.43ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.33ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.55ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.36ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.41ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.35ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.40ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.33ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.39ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.35ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.37ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.34ms
# WARNING:tornado.access:404 GET /assignments/Regression%20task/custom.css (127.0.0.1) 0.42ms
# WARNING:tornado.access:404 GET /assignments/Regression%20task/custom.css (127.0.0.1) 0.34ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.90ms
# WARNING:tornado.access:404 GET /custom.css (127.0.0.1) 0.48ms
# WARNING:tornado.access:404 GET /favicon.ico (127.0.0.1) 0.42ms

# %% [markdown]
# # Convert to pdf
# - Try to_pdf directly
#     - Only is pdf file
#         - doesn't exist
#         - or exists but is older than source
#     - If fail: put file on list
#     - All files on list: try converting via slides

# %%
ph.publish(slides=False, root_nb=root_nb, pdf=True, git=False, Debug=False)
# Out:
# http://localhost:8888/notebooks/NYU/Transformations.ipynb  is NOT local
# 	pdf file needs to be updated: pdf/Categorical_Variables slides.pdf
# jupyter nbconvert --to pdf 'Categorical_Variables.ipynb' (rc=1):
# jupyter nbconvert --to pdf 'Classification_Baseline_Model.ipynb' (rc=1):
# 	pdf file needs to be updated: pdf/Classification_Loss_Function slides.pdf
# jupyter nbconvert --to pdf 'Classification_Loss_Function.ipynb' (rc=1):
# 	pdf file needs to be updated: pdf/Classification_Notebook_Overview slides.pdf
# jupyter nbconvert --to pdf 'Classification_Notebook_Overview.ipynb' (rc=1):
# 	pdf file needs to be updated: pdf/Classification_Overview slides.pdf
# jupyter nbconvert --to pdf 'Classification_Overview.ipynb' (rc=1):
# 	pdf file needs to be updated: pdf/Classification_and_Non_Numerical_Data slides.pdf
# jupyter nbconvert --to pdf 'Classification_and_Non_Numerical_Data.ipynb' (rc=1):
# jupyter nbconvert --to pdf 'Dummy_Variable_Trap.ipynb' (rc=1):
# jupyter nbconvert --to pdf 'Error_Analysis.ipynb' (rc=1):
# jupyter nbconvert --to pdf 'Error_Analysis_MNIST.ipynb' (rc=1):
# jupyter nbconvert --to pdf 'Error_Analysis_Overview.ipynb' (rc=1):
# jupyter nbconvert --to pdf 'Loss_functions.ipynb' (rc=1):
# 	pdf file needs to be updated: pdf/Multinomial_Classification slides.pdf
# jupyter nbconvert --to pdf 'Multinomial_Classification.ipynb' (rc=1):
# 	pdf file needs to be updated: pdf/Prepare_data_Overview slides.pdf
# jupyter nbconvert --to pdf 'Prepare_data_Overview.ipynb' (rc=1):
# jupyter nbconvert --to pdf 'Training_Loss.ipynb' (rc=1):
# jupyter nbconvert --to pdf 'Transformations.ipynb' (rc=1):
# jupyter nbconvert --to pdf 'Transformations_Mechanics.ipynb' (rc=1):
# jupyter nbconvert --to pdf 'Transformations_Overview.ipynb' (rc=1):
# jupyter nbconvert --to pdf 'assignments/Regression task/Using_Machine_Learning_for_Hedging.ipynb' (rc=1):
# Failed match of file beautify_plots.py with .ipynb tail
# Try failed to_pdf with to_slides:  ['Categorical_Variables.ipynb', 'Classification_Baseline_Model.ipynb', 'Classification_Loss_Function.ipynb', 'Classification_Notebook_Overview.ipynb', 'Classification_Overview.ipynb', 'Classification_and_Non_Numerical_Data.ipynb', 'Dummy_Variable_Trap.ipynb', 'Error_Analysis.ipynb', 'Error_Analysis_MNIST.ipynb', 'Error_Analysis_Overview.ipynb', 'Loss_functions.ipynb', 'Multinomial_Classification.ipynb', 'Prepare_data_Overview.ipynb', 'Training_Loss.ipynb', 'Transformations.ipynb', 'Transformations_Mechanics.ipynb', 'Transformations_Overview.ipynb', 'assignments/Regression task/Using_Machine_Learning_for_Hedging.ipynb']

# %% [markdown]
# ## Re-run the cell that starts the server: --post serve
